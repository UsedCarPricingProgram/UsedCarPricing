# %%
#导入相关包
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# %matplotlib inline

# %%
df = pd.read_excel('./data/cleaned_car_all.xlsx')
df.head(10)
# Out:
#    Unnamed: 0                         title  price  price_new date_regi  \
# 0           0      荣威e950 2017款 50T 混动互联行政版  11.56      27.78   2019-07
# 1           1        WEY VV7 2017款 2.0T 旗舰型   7.80      20.49   2017-11
# 2           2    雪佛兰 迈锐宝XL 2017款 1.5T 自动锐驰版   7.71      21.16   2017-06
# 3           3  本田XR-V 2017款 1.8L EXi CVT舒适版  10.10      16.26   2019-03
# 4           4    现代 领动 2019款 1.5L CVT智炫·精英型   7.07      13.00   2020-01
# 5           5       北汽威旺M50F 2017款 1.5L 舒适型   2.93       7.36   2017-12
# 6           6  起亚 智跑 2019款 1.4T DCT智享豪华版GLS   9.66      15.73   2019-10
# 7           7  奇瑞 小蚂蚁 2021款 15万蚁粉款 蚁炫版 磷酸铁锂   5.45       7.38   2020-11
# 8           8     雪佛兰 科迈罗 2017款 2.0T RS(进口)  26.60      43.41   2019-03
# 9           9      吉利汽车 远景 2018款 1.5L 手动幸福版   3.85       6.50   2019-01
#
#    mileage  official_endurance standard  gearbox  num_trans  license_location  \
# 0      5.0                 NaN       国五        1        0.0                 1
# 1      9.5                 NaN       国五        1        2.0                 0
# 2      6.5                 NaN       国五        1        1.0                 0
# 3      1.6                 NaN       国五        1        1.0                 0
# 4      5.1                 NaN      国六b        1        0.0                 0
# 5      6.1                 NaN       国五        0        1.0                 0
# 6      3.3                 NaN      国六b        1        2.0                 0
# 7      4.6               301.0      新能源        1        1.0                 1
# 8      3.5                 NaN       国五        1        4.0                 0
# 9      4.2                 NaN       国五        0        1.0                 0
#
#    color  motor_power  battery_capacity battery_type  energy_type  \
# 0      0          NaN               NaN          NaN          2.0
# 1      0          NaN               NaN          NaN          0.0
# 2      0          NaN               NaN          NaN          0.0
# 3      0          NaN               NaN          NaN          0.0
# 4      0          NaN               NaN          NaN          0.0
# 5      0          NaN               NaN          NaN          0.0
# 6      0          NaN               NaN          NaN          0.0
# 7      1         30.0              35.0            -          1.0
# 8      1          NaN               NaN          NaN          0.0
# 9      0          NaN               NaN          NaN          0.0
#
#    displacement  keys     brand
# 0          1.96   2.0    荣威e950
# 1          2.80   1.0       WEY
# 2          2.10   1.0       雪佛兰
# 3          1.80   1.0    本田XR-V
# 4          1.50   1.0        现代
# 5          1.50   1.0  北汽威旺M50F
# 6          1.96   1.0        起亚
# 7           NaN   2.0        奇瑞
# 8          2.80   1.0       雪佛兰
# 9          1.50   1.0      吉利汽车

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# title                  object
# price                 float64
# price_new             float64
# date_regi              object
# mileage               float64
# official_endurance    float64
# standard               object
# gearbox                 int64
# num_trans             float64
# license_location        int64
# color                   int64
# motor_power           float64
# battery_capacity      float64
# battery_type           object
# energy_type           float64
# displacement          float64
# keys                  float64
# brand                  object
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0         price     price_new       mileage  \
# count  39216.000000  39159.000000  39159.000000  39159.000000
# mean   19607.500000     13.459436     22.786334      4.708275
# std    11320.828415     10.780845     16.292553      3.165136
# min        0.000000      1.330000      2.880000      0.000000
# 25%     9803.750000      6.630000     12.790000      2.200000
# 50%    19607.500000      9.800000     17.360000      4.300000
# 75%    29411.250000     17.100000     29.180000      6.700000
# max    39215.000000    100.000000    389.550000     19.900000
#
#        official_endurance       gearbox     num_trans  license_location  \
# count         5075.000000  39216.000000  39159.000000      39216.000000
# mean           382.722365      0.940764      0.870298          0.065432
# std            143.460601      0.236069      0.908195          0.247291
# min             53.000000      0.000000      0.000000          0.000000
# 25%            301.000000      1.000000      0.000000          0.000000
# 50%            401.000000      1.000000      1.000000          0.000000
# 75%            500.000000      1.000000      1.000000          0.000000
# max            732.000000      1.000000      9.000000          1.000000
#
#               color  motor_power  battery_capacity   energy_type  \
# count  39216.000000  5075.000000       4931.000000  39214.000000
# mean       0.249949   134.392197         46.718110      0.245856
# std        0.432989   102.416012         19.548578      0.557707
# min        0.000000    15.000000          8.000000      0.000000
# 25%        0.000000    40.000000         33.000000      0.000000
# 50%        0.000000   120.000000         44.000000      0.000000
# 75%        0.000000   202.000000         60.000000      0.000000
# max        1.000000   577.000000        100.000000      2.000000
#
#        displacement          keys
# count  34106.000000  39214.000000
# mean       2.200374      1.303106
# std        0.584195      0.464958
# min        0.000000      0.000000
# 25%        1.800000      1.000000
# 50%        2.100000      1.000000
# 75%        2.800000      2.000000
# max       28.000000      5.000000

# %%
#将新车价格对数化
df['price_log'] = df['price_new'].apply(np.log1p)

#增加「rate_residual」
df['rate_residual'] = df['price']/df['price_new']

#计算「使用天数」
now=datetime(2022,11,8)
df['date_regi'] = pd.to_datetime(df['date_regi'], format='%Y-%m')
df['num_day']=df['date_regi'].apply(lambda x: now-x)
df['num_day']=df['num_day'].apply(lambda x: x.days)
df.head(10)
# Out:
#    Unnamed: 0                         title  price  price_new  date_regi  \
# 0           0      荣威e950 2017款 50T 混动互联行政版  11.56      27.78 2019-07-01
# 1           1        WEY VV7 2017款 2.0T 旗舰型   7.80      20.49 2017-11-01
# 2           2    雪佛兰 迈锐宝XL 2017款 1.5T 自动锐驰版   7.71      21.16 2017-06-01
# 3           3  本田XR-V 2017款 1.8L EXi CVT舒适版  10.10      16.26 2019-03-01
# 4           4    现代 领动 2019款 1.5L CVT智炫·精英型   7.07      13.00 2020-01-01
# 5           5       北汽威旺M50F 2017款 1.5L 舒适型   2.93       7.36 2017-12-01
# 6           6  起亚 智跑 2019款 1.4T DCT智享豪华版GLS   9.66      15.73 2019-10-01
# 7           7  奇瑞 小蚂蚁 2021款 15万蚁粉款 蚁炫版 磷酸铁锂   5.45       7.38 2020-11-01
# 8           8     雪佛兰 科迈罗 2017款 2.0T RS(进口)  26.60      43.41 2019-03-01
# 9           9      吉利汽车 远景 2018款 1.5L 手动幸福版   3.85       6.50 2019-01-01
#
#    mileage  official_endurance standard  gearbox  num_trans  ...  motor_power  \
# 0      5.0                 NaN       国五        1        0.0  ...          NaN
# 1      9.5                 NaN       国五        1        2.0  ...          NaN
# 2      6.5                 NaN       国五        1        1.0  ...          NaN
# 3      1.6                 NaN       国五        1        1.0  ...          NaN
# 4      5.1                 NaN      国六b        1        0.0  ...          NaN
# 5      6.1                 NaN       国五        0        1.0  ...          NaN
# 6      3.3                 NaN      国六b        1        2.0  ...          NaN
# 7      4.6               301.0      新能源        1        1.0  ...         30.0
# 8      3.5                 NaN       国五        1        4.0  ...          NaN
# 9      4.2                 NaN       国五        0        1.0  ...          NaN
#
#    battery_capacity  battery_type  energy_type displacement  keys     brand  \
# 0               NaN           NaN          2.0         1.96   2.0    荣威e950
# 1               NaN           NaN          0.0         2.80   1.0       WEY
# 2               NaN           NaN          0.0         2.10   1.0       雪佛兰
# 3               NaN           NaN          0.0         1.80   1.0    本田XR-V
# 4               NaN           NaN          0.0         1.50   1.0        现代
# 5               NaN           NaN          0.0         1.50   1.0  北汽威旺M50F
# 6               NaN           NaN          0.0         1.96   1.0        起亚
# 7              35.0             -          1.0          NaN   2.0        奇瑞
# 8               NaN           NaN          0.0         2.80   1.0       雪佛兰
# 9               NaN           NaN          0.0         1.50   1.0      吉利汽车
#
#    price_log rate_residual  num_day
# 0   3.359681      0.416127   1226.0
# 1   3.067588      0.380673   1833.0
# 2   3.098289      0.364367   1986.0
# 3   2.848392      0.621156   1348.0
# 4   2.639057      0.543846   1042.0
# 5   2.123458      0.398098   1803.0
# 6   2.817204      0.614113   1134.0
# 7   2.125848      0.738482    737.0
# 8   3.793465      0.612762   1348.0
# 9   2.014903      0.592308   1407.0
#
# [10 rows x 22 columns]

# %%
sns.set_style('ticks')
fig, ax = plt.subplots(1,3,constrained_layout=True, figsize=(16, 4), dpi=180)
#不同gearbox的保值率分布
axesSub = sns.violinplot(data=df,y='rate_residual',x='gearbox',split=True,ax=ax[0])
axesSub.set_title('rate_residual distribution of gearbox')
#不同num_trans的保值率分布
sns.violinplot(data=df,y='rate_residual',x='num_trans',split=True,ax=ax[1])
axesSub.set_title('rate_residual distribution of num_trans') 
#不同energy_type的保值率分布
sns.violinplot(data=df,y='rate_residual',x='energy_type',split=True,ax=ax[2])
axesSub.set_title('rate_residual distribution of energy_type')
# Out:
# Text(0.5, 1.0, 'rate_residual distribution of energy_type')

# %%
#不同license_location的保值率分布
sns.set_style('ticks')
fig, ax = plt.subplots(1,3,constrained_layout=True, figsize=(16, 4), dpi=180)
axesSub = sns.violinplot(data=df,y='rate_residual',x='license_location',split=True,ax=ax[0])
axesSub.set_title=('rate_residual distribution of license_location')
#不同color的保值率分布
axesSub = sns.violinplot(data=df,y='rate_residual',x='color',split=True,ax=ax[1])
axesSub.set_title=('rate_residual distribution of color')
axesSub = sns.violinplot(data=df,y='rate_residual',x='standard',split=True,ax=ax[2])
axesSub.set_title=('standard distribution of color')
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22269 (\N{CJK UNIFIED IDEOGRAPH-56FD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20116 (\N{CJK UNIFIED IDEOGRAPH-4E94}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20845 (\N{CJK UNIFIED IDEOGRAPH-516D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26032 (\N{CJK UNIFIED IDEOGRAPH-65B0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33021 (\N{CJK UNIFIED IDEOGRAPH-80FD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28304 (\N{CJK UNIFIED IDEOGRAPH-6E90}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22235 (\N{CJK UNIFIED IDEOGRAPH-56DB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set_style('ticks')
fig, ax = plt.subplots(1,3,constrained_layout=True, figsize=(16, 4), dpi=180)
#里程分布
axesSub=sns.histplot(df['mileage'],bins=20,kde=True,ax=ax[0])

#价格分布
axesSub=sns.histplot(df['price_log'],bins=20,kde=True,ax=ax[1])

#官方续航分布
axesSub=sns.histplot(df['official_endurance'],bins=20,kde=True,ax=ax[2])

# %%
df1=df.loc[:,['rate_residual','mileage','num_day','energy_type']]
sns.pairplot(df1, hue="energy_type")

# %%
df1=df.loc[:,['price','mileage','num_day','gearbox']]
sns.pairplot(df1, hue="gearbox")

# %%
df1=df.loc[:,['price','mileage','displacement','color']]
sns.pairplot(df1, hue="color")

# %%
# types=df['energy_type'].isin([0,1,2])
# sns.displot(pd.DataFrame({'price':np.log10(df[types]['price']),'energy_type':df[types]['energy_type']}),
#             x='price',hue='energy_type',kind='kde');

# %%
# sns.set_style('ticks')
# fig, ax = plt.subplots(1,3,constrained_layout=True, figsize=(16, 4), dpi=180)
#里程分布
types=df['energy_type'].isin([0,1,2])

axesSub=sns.displot(pd.DataFrame({'price':np.log10(df[types]['price']),'energy_type':df[types]['energy_type']}),
            x='price',hue='energy_type',kind='kde',);
#不同颜色二手车的价格分布
types=df['color'].isin([0,1])
axesSub=sns.displot(pd.DataFrame({'price':np.log10(df[types]['price']),'color':df[types]['color']}),
            x='price',hue='color',kind='kde',ax=ax[1]);
#不同位置的价格分布
types=df['license_location'].isin([0,1])
axesSub=sns.displot(pd.DataFrame({'price':np.log10(df[types]['price']),'license_location':df[types]['license_location']}),
            x='price',hue='license_location',kind='kde',ax=ax[2]);


#可看出汽车类型（0）二手车数量多，均值大概在8w左右，电车（1）均值小于8w，而混动均值大概25w，
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2148: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try kdeplot.
#   warnings.warn(msg, UserWarning)
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2148: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try kdeplot.
#   warnings.warn(msg, UserWarning)

# %%
#不同energy_type的价格分布
ax=sns.boxplot(x='energy_type',y='price',data=df[types],fliersize=0)
ax.set_ylim([0,60]);

# %%
# ax=plt.subplots(figsize=(6,6))
# columns=['price','price_new','mileage','keys','energy_type','num_day']
# sns.heatmap(df[columns].corr(),annot=True,cmap='RdYlGn',ax=ax);

plt.subplots(figsize=(8,8),dpi=120,facecolor='w')# 设置画布大小，分辨率，和底色
df4=df.loc[:,['price','price_new','mileage','official_endurance','standard'
              ,'gearbox','num_trans','license_location'
              ,'color','motor_power','battery_capacity'
              ,'battery_type','num_day','energy_type','keys',]]
#annot为热力图上显示数据；fmt='.1g'为数据保留两位有效数字,square呈现正方形，vmax最大值为1

sns.heatmap(df4.corr(), annot=True, vmax=1, square=True, fmt='.1g')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('ticks')
fig, ax = plt.subplots(1,3,constrained_layout=True, figsize=(16, 4), dpi=180)
axesSub = sns.scatterplot(x = "displacement", y = "price", data = df, alpha = 0.003, ax=ax[0])
axesSub.set_title('displacement and price')
axesSub = sns.scatterplot(x = "official_endurance", y = "price", data = df,alpha = 0.003, ax=ax[1])
axesSub.set_title('official_endurance and Day Number')
axesSub = sns.scatterplot(x = "price_new", y = "price", data = df, alpha = 0.003, ax=ax[2])
axesSub.set_title('new_price and price')
# Out:
# Text(0.5, 1.0, 'new_price and price')

# %%
#df['price_log'] = df['price'].apply(np.log1p)
from matplotlib import colors
color = np.random.rand(39159) # 随机产生用于映射颜色的数值
#size = 500 * np.random.rand(50) # 随机改变散点大小的数值
changecolor = colors.Normalize(vmin=0.4, vmax=0.8)
#plt.scatter(x, y, c=color, s = size, alpha=0.3, cmap='viridis', norm=changecolor)
# plt.colorbar() # 显示颜色条
# plt.show()



sns.set_style('ticks')
fig, ax = plt.subplots(1,3,constrained_layout=True, figsize=(16, 4), dpi=180)
axesSub = sns.scatterplot(x = "mileage", y = "rate_residual",c=color, alpha=0.003, data = df,  ax=ax[0])
axesSub.set_title('Mileage and rate_residual')



axesSub = sns.scatterplot(x = "mileage", y = "num_day", data = df,c=color,alpha = 0.003, ax=ax[1])
axesSub.set_title('Mileage and Day Number')
axesSub = sns.scatterplot(x = "num_day", y = "rate_residual"
                         , data = df, alpha = 0.003, c=color,ax=ax[2])
axesSub.set_title('Day Number and Residual Rate')
# Out:
# Text(0.5, 1.0, 'Day Number and Residual Rate')
