# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
from pylab import mpl


import brewer2mpl
#调颜色
bmap = brewer2mpl.get_map('PuBu', 'Sequential', 3)

colors = bmap.mpl_colors

import seaborn as sns

# %%
import matplotlib
matplotlib.matplotlib_fname()
from matplotlib.font_manager import FontManager
fm = FontManager()
mat_fonts = set(f.name for f in fm.ttflist)

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
df_p= pd.read_excel('/Users/apple/Desktop/progrmming_project/UsedCarPricing/data/cleaneddata/cleaned_car_all.xlsx',sheet_name='petrol',index_col=0)
df_e =pd.read_excel('/Users/apple/Desktop/progrmming_project/UsedCarPricing/data/cleaneddata/cleaned_car_all.xlsx',sheet_name='electric',index_col=0)
df_m =pd.read_excel('/Users/apple/Desktop/progrmming_project/UsedCarPricing/data/cleaneddata/cleaned_car_all.xlsx',sheet_name='mixed',index_col=0)
df=pd.read_excel('/Users/apple/Desktop/progrmming_project/UsedCarPricing/data/cleaneddata/cleaned_car_all.xlsx',index_col=0)
df.head(40)
# Out:
#                                          title  price  price_new  date_regi  \
# index
# 0                    荣威i5 2020款 1.5L 自动4G互联领豪版   6.10       9.54 2021-04-01
# 1                  丰田 雷凌 2019款 185T CVT进取版 国VI   8.73      12.57 2020-07-01
# 2                宝骏730 2019款 1.5L 手动超值型 7座 国VI   4.93       6.93 2020-09-01
# 3                     别克 昂科拉 2021款 332T CVT精英型   9.08      15.84 2021-04-01
# 4                   现代 领动 2019款 1.5L CVT智炫·精英型   7.00      13.00 2020-01-01
# 5          日产 奇骏 2021款 VC-Turbo 300 CVT 2WD豪华版  15.68      21.70 2022-01-01
# 6                     大众 宝来 2021款 1.5L 自动舒适智联版   9.25      14.76 2021-03-01
# 7             大众 2019款 改款 宝来·传奇 1.5L 自动时尚型 国VI   7.38      11.81 2021-06-01
# 8                 起亚 智跑 2019款 1.4T DCT智享豪华版GLS   9.49      15.73 2019-10-01
# 9                      大众 桑塔纳 2021款 1.5L 手动风尚版   5.88       9.43 2022-07-01
# 10             本田 凌派 2019款 180Turbo CVT豪华版 国VI   7.15      13.00 2019-12-01
# 11          北京BJ40 2019款 PLUS 2.3T 自动四驱尊享版 国VI  12.25      20.07 2019-09-01
# 12                    WEY VV6 2020款 2.0T 两驱智护+   9.98      16.82 2020-01-01
# 13                奔驰C级 2020款 改款 C 200 L 时尚型运动版  22.96      34.28 2020-07-01
# 14              丰田 卡罗拉 2021款 1.2T S-CVT先锋PLUS版   9.05      13.33 2021-07-01
# 15       奔驰GLC级 2022款 改款三 GLC 260 L 4MATIC 动感型  38.49      44.10 2022-05-01
# 16            广汽传祺 传祺GA4 2021款 PLUS 235T 自动尊享版   7.11       9.96 2021-03-01
# 17              大众 揽境 2021款 380TSI 四驱R-Line拓境版  26.58      37.22 2021-06-01
# 18             丰田 卡罗拉 2019款 1.2T S-CVT GL-i豪华版  10.09      14.74 2020-07-01
# 19                     大众 桑塔纳 2021款 1.5L 手动风尚版   5.05       9.43 2020-12-01
# 20                    MINI 2021款 1.5T ONE PLUS  17.81      21.90 2020-11-01
# 21                   马自达CX-30 2021款 2.0L 自动尚悦型  11.27      15.19 2022-01-01
# 22                现代 悦动 2018款 1.6L 自动悦目版GL 国VI   5.83       9.22 2020-06-01
# 23          上汽大通MAXUS 上汽大通G50 2020款 1.5T 自动精英版   7.84      11.92 2021-10-01
# 24             丰田 YARiS L 致炫 2020款 1.5L CVT领先版   6.35       9.31 2020-02-01
# 25     奔驰GLC级 2022款 改款 GLC 300 L 4MATIC 动感型臻藏版  42.38      49.05 2022-11-01
# 26            吉利汽车 博越 2021款 百万款 1.8TD DCT两驱舒适型   8.58      10.83 2021-08-01
# 27                 荣威i5 2020款 1.5L 自动4G互联领豪旗舰版   5.63      10.08 2020-04-01
# 28       本田 思域 2021款 HATCHBACK 220TURBO CVT潮酷控  12.13      16.60 2021-04-01
# 29             宝马X4 2021款 xDrive 25i M运动套装(进口)  36.78      49.49 2021-02-01
# 30                      捷达VA3 2019款 1.5L 自动悦享版   6.25       9.10 2020-09-01
# 31          本田CR-V 2019款 240TURBO CVT两驱舒适版 国VI  13.88      19.52 2020-04-01
# 32               奇瑞 瑞虎3X 2021款 钻石版 1.5L CVT3克拉   5.40       7.15 2021-10-01
# 33                    领克05 2020款 2.0TD 四驱劲Halo  15.98      23.10 2020-09-01
# 34               Jeep 牧马人 2022款 2.0T 高地四门版(进口)  47.70      52.09 2022-09-01
# 35                       凯迪拉克CT4 2020款 28T 时尚型  17.77      26.02 2021-01-01
# 36                   大众CC 2020款 330TSI 魅颜版 国VI  19.48      28.53 2020-06-01
# 37               大众 2021款 途安L 280TSI DSG舒适版 7座  11.32      18.00 2021-03-01
# 38                    宝马3系 2021款 改款二 320i 运动套装  24.23      31.90 2021-07-01
# 39                    起亚K3 2019款 1.5L CVT智享互联版   7.28      12.57 2020-01-01
#
#        mileage standard  gearbox  num_trans  license_location  color  \
# index
# 0         1.40      国六b        1          1                 0      0
# 1         1.80      国六b        1          1                 0      0
# 2         4.90      国六b        0          0                 0      0
# 3         1.40      国六b        1          1                 0      0
# 4         5.10      国六b        1          0                 0      0
# 5         1.40      国六b        1          1                 0      0
# 6         0.40      国六b        1          0                 0      0
# 7         3.30      国六b        1          1                 0      0
# 8         3.30      国六b        1          2                 0      0
# 9         0.40      国六b        0          0                 0      0
# 10        3.10      国六b        1          2                 0      0
# 11        4.90      国六b        1          0                 0      1
# 12        3.50      国六b        1          0                 0      0
# 13        3.70      国六b        1          2                 0      1
# 14        0.80      国六b        1          1                 0      0
# 15        0.10      国六b        1          1                 0      0
# 16        1.50      国六b        1          1                 0      0
# 17        0.60      国六b        1          1                 0      1
# 18        0.70      国六b        1          1                 0      0
# 19        1.10      国六b        0          0                 0      0
# 20        2.50      国六b        1          0                 0      0
# 21        0.90      国六b        1          1                 0      1
# 22        7.10      国六b        1          0                 0      0
# 23        3.00      国六b        1          1                 0      0
# 24        2.90      国六b        1          0                 1      0
# 25        0.01      国六b        1          0                 0      0
# 26        0.90      国六b        1          0                 0      0
# 27        4.20      国六b        1          2                 0      0
# 28        2.10      国六b        1          0                 0      0
# 29        1.30      国六b        1          0                 0      0
# 30        7.20      国六b        1          0                 0      0
# 31        5.60      国六b        1          0                 0      0
# 32        0.50      国六b        1          1                 0      0
# 33        1.30      国六b        1          1                 0      0
# 34        0.02      国六b        1          1                 0      0
# 35        2.70      国六b        1          1                 0      1
# 36        2.40      国六b        1          0                 0      0
# 37        3.40      国六b        1          2                 1      0
# 38        3.20      国六b        1          0                 0      0
# 39        5.00      国六b        1          1                 0      0
#
#        energy_type  displacement  keys brand  city  price_log  rate_residual  \
# index
# 0                0          1.50     2    荣威     1   2.355178       0.639413
# 1                0          1.68     2    丰田     1   2.607861       0.694511
# 2                0          1.50     1    宝骏     1   2.070653       0.711400
# 3                0          1.82     1    别克     1   2.823757       0.573232
# 4                0          1.50     1    现代     1   2.639057       0.538462
# 5                0          2.10     1  东风日产     1   3.122365       0.722581
# 6                0          1.50     2    大众     1   2.757475       0.626694
# 7                0          1.50     1    大众     1   2.550226       0.624894
# 8                0          1.96     1    起亚     1   2.817204       0.603306
# 9                0          1.50     2    大众     1   2.344686       0.623542
# 10               0          1.40     2    本田     1   2.639057       0.550000
# 11               0          3.22     1    北京     1   3.047850       0.610364
# 12               0          2.80     2   WEY     1   2.880321       0.593341
# 13               0          2.10     1    奔驰     1   3.563316       0.669778
# 14               0          1.68     2    丰田     1   2.662355       0.678920
# 15               0          2.80     2    奔驰     1   3.808882       0.872789
# 16               0          2.10     1    广汽     1   2.394252       0.713855
# 17               0          2.80     2    大众     1   3.643359       0.714132
# 18               0          1.68     1    丰田     1   2.756205       0.684532
# 19               0          1.50     2    大众     1   2.344686       0.535525
# 20               0          2.10     2  MINI     1   3.131137       0.813242
# 21               0          2.00     1   马自达     1   2.784394       0.741935
# 22               0          1.60     1    现代     1   2.324347       0.632321
# 23               0          2.10     1  上汽大通     1   2.558776       0.657718
# 24               0          1.50     2    丰田     1   2.333114       0.682062
# 25               0          2.80     2    奔驰     1   3.913023       0.864016
# 26               0          2.52     1  吉利汽车     1   2.470639       0.792244
# 27               0          1.50     1    荣威     1   2.405142       0.558532
# 28               0          2.10     1    本田     1   2.867899       0.730723
# 29               0          2.80     2    宝马     1   3.921775       0.743180
# 30               0          1.50     1    捷达     1   2.312535       0.686813
# 31               0          2.10     1    本田     1   3.021400       0.711066
# 32               0          1.50     1    奇瑞     1   2.098018       0.755245
# 33               0          2.80     2    领克     1   3.182212       0.691775
# 34               0          2.80     2  Jeep     1   3.971989       0.915723
# 35               0          2.80     1  凯迪拉克     1   3.296577       0.682936
# 36               0          2.80     2    大众     1   3.385407       0.682790
# 37               0          1.96     1    大众     1   2.944439       0.628889
# 38               0          2.80     1    宝马     1   3.493473       0.759561
# 39               0          1.50     1    起亚     1   2.607861       0.579157
#
#        num_day  newness_rate  mile_per_day
# index
# 0          586      0.892968      0.002389
# 1          860      0.842922      0.002093
# 2          798      0.854247      0.006140
# 3          586      0.892968      0.002389
# 4         1042      0.809680      0.004894
# 5          311      0.943196      0.004502
# 6          617      0.887306      0.000648
# 7          525      0.904110      0.006286
# 8         1134      0.792877      0.002910
# 9          130      0.976256      0.003077
# 10        1073      0.804018      0.002889
# 11        1164      0.787397      0.004210
# 12        1042      0.809680      0.003359
# 13         860      0.842922      0.004302
# 14         495      0.909589      0.001616
# 15         191      0.965114      0.000524
# 16         617      0.887306      0.002431
# 17         525      0.904110      0.001143
# 18         860      0.842922      0.000814
# 19         707      0.870868      0.001556
# 20         737      0.865388      0.003392
# 21         311      0.943196      0.002894
# 22         890      0.837443      0.007978
# 23         403      0.926393      0.007444
# 24        1011      0.815342      0.002868
# 25           7      0.998721      0.001429
# 26         464      0.915251      0.001940
# 27         951      0.826301      0.004416
# 28         586      0.892968      0.003584
# 29         645      0.882192      0.002016
# 30         798      0.854247      0.009023
# 31         951      0.826301      0.005889
# 32         403      0.926393      0.001241
# 33         798      0.854247      0.001629
# 34          68      0.987580      0.000294
# 35         676      0.876530      0.003994
# 36         890      0.837443      0.002697
# 37         617      0.887306      0.005511
# 38         495      0.909589      0.006465
# 39        1042      0.809680      0.004798

# %%
df_p.describe()
# Out:
#               price     price_new       mileage       gearbox     num_trans  \
# count  66565.000000  66565.000000  66565.000000  66565.000000  66565.000000
# mean      13.470164     23.128488      4.742308      0.936829      0.914730
# std       10.465508     15.988945      3.127717      0.243273      0.939137
# min        1.080000      3.680000      0.000000      0.000000      0.000000
# 25%        6.910000     13.010000      2.300000      1.000000      0.000000
# 50%       10.000000     17.360000      4.300000      1.000000      1.000000
# 75%       16.850000     29.180000      6.700000      1.000000      1.000000
# max      100.000000    389.550000     19.900000      1.000000     59.000000
#
#        license_location         color  energy_type  displacement  \
# count      66565.000000  66565.000000      66565.0  66565.000000
# mean           0.051153      0.225945          0.0      2.208825
# std            0.220311      0.418206          0.0      0.568783
# min            0.000000      0.000000          0.0      0.000000
# 25%            0.000000      0.000000          0.0      1.800000
# 50%            0.000000      0.000000          0.0      2.100000
# 75%            0.000000      0.000000          0.0      2.800000
# max            1.000000      1.000000          0.0     28.000000
#
#                keys          city     price_log  rate_residual       num_day  \
# count  66565.000000  66565.000000  66565.000000   66565.000000  66565.000000
# mean       1.320183      2.143454      3.024554       0.577555   1293.031864
# std        0.469983      0.705992      0.539749       0.145600    676.981157
# min        0.000000      1.000000      1.543298       0.103602      7.000000
# 25%        1.000000      2.000000      2.639771       0.469038    737.000000
# 50%        1.000000      2.000000      2.910174       0.581727   1256.000000
# 75%        2.000000      3.000000      3.407179       0.682997   1803.000000
# max        5.000000      3.000000      5.967556       1.615894   4604.000000
#
#        newness_rate  mile_per_day
# count  66565.000000  66565.000000
# mean       0.763830      0.003665
# std        0.123650      0.002364
# min        0.159087      0.000000
# 25%        0.670685      0.002454
# 50%        0.770594      0.003455
# 75%        0.865388      0.004586
# max        0.998721      0.185714

# %%
df_e.describe()
# Out:
#               price     price_new       mileage  official_endurance  \
# count  11776.000000  11776.000000  11776.000000        11776.000000
# mean      13.014372     17.284760      2.273997          398.276473
# std        9.531708     12.673419      2.185183          135.540466
# min        1.330000      2.880000      0.010000          116.000000
# 25%        6.160000      7.380000      0.700000          301.000000
# 50%        9.980000     13.880000      1.600000          401.000000
# 75%       18.980000     25.690000      3.200000          500.000000
# max       96.450000    114.800000     16.300000          732.000000
#
#             gearbox     num_trans  license_location         color  \
# count  11776.000000  11776.000000      11776.000000  11776.000000
# mean       0.999830      0.698879          0.163213      0.367188
# std        0.013032      0.768611          0.369576      0.482059
# min        0.000000      0.000000          0.000000      0.000000
# 25%        1.000000      0.000000          0.000000      0.000000
# 50%        1.000000      1.000000          0.000000      0.000000
# 75%        1.000000      1.000000          0.000000      1.000000
# max        1.000000      6.000000          1.000000      1.000000
#
#         motor_power  battery_capacity  energy_type          keys  \
# count  11776.000000      11776.000000      11776.0  11776.000000
# mean     121.702917         47.405449          1.0      1.302055
# std       95.223232         20.099836          0.0      0.466326
# min       15.000000          9.000000          1.0      0.000000
# 25%       40.000000         33.000000          1.0      1.000000
# 50%      105.000000         47.000000          1.0      1.000000
# 75%      175.000000         60.000000          1.0      2.000000
# max      577.000000        100.000000          1.0      5.000000
#
#                city     price_log  rate_residual       num_day  newness_rate  \
# count  11776.000000  11776.000000   11776.000000  11776.000000  11776.000000
# mean       1.809952      2.694993       0.799781    639.817340      0.883138
# std        0.752557      0.652492       0.219021    510.325403      0.093210
# min        1.000000      1.355835       0.083753      7.000000      0.498082
# 25%        1.000000      2.125848       0.707503    280.000000      0.854247
# 50%        2.000000      2.700018       0.853309    495.000000      0.909589
# 75%        2.000000      3.284289       0.940367    798.000000      0.948858
# max        3.000000      4.751865       1.484950   2748.000000      0.998721
#
#        mile_per_day
# count  11776.000000
# mean       0.003445
# std        0.002589
# min        0.000006
# 25%        0.001742
# 50%        0.003030
# 75%        0.004651
# max        0.028571

# %%
df_m.describe()
# Out:
#              price    price_new      mileage  official_endurance      gearbox  \
# count  6728.000000  6728.000000  6728.000000         1062.000000  6728.000000
# mean     23.238422    32.531134     2.672985          178.471751     0.999703
# std      13.921463    17.669801     2.409180           19.513273     0.017240
# min       3.460000    11.160000     0.010000           53.000000     0.000000
# 25%      13.180000    20.440000     0.900000          180.000000     1.000000
# 50%      22.430000    32.000000     2.100000          180.000000     1.000000
# 75%      27.600000    37.640000     3.800000          188.000000     1.000000
# max      99.800000   160.110000    17.600000          246.000000     1.000000
#
#          num_trans  license_location        color  motor_power  \
# count  6728.000000       6728.000000  6728.000000  1068.000000
# mean      0.734245          0.116082     0.208532   261.794007
# std       0.751672          0.320347     0.406289    73.932989
# min       0.000000          0.000000     0.000000    60.000000
# 25%       0.000000          0.000000     0.000000   240.000000
# 50%       1.000000          0.000000     0.000000   245.000000
# 75%       1.000000          0.000000     0.000000   245.000000
# max       8.000000          1.000000     1.000000   510.000000
#
#        battery_capacity  energy_type  displacement         keys         city  \
# count        1068.00000       6728.0   5657.000000  6728.000000  6728.000000
# mean           39.11236          2.0      2.297723     1.431629     2.000000
# std             3.56681          0.0      0.612642     0.498332     0.796715
# min             8.00000          2.0      0.000000     1.000000     1.000000
# 25%            40.00000          2.0      1.960000     1.000000     1.000000
# 50%            40.00000          2.0      2.100000     1.000000     2.000000
# 75%            40.00000          2.0      2.800000     2.000000     3.000000
# max            44.00000          2.0      4.200000     4.000000     3.000000
#
#          price_log  rate_residual      num_day  newness_rate  mile_per_day
# count  6728.000000    6728.000000  6728.000000   6728.000000   6728.000000
# mean      3.406366       0.706940   624.444857      0.885946      0.003985
# std       0.445957       0.134034   431.801717      0.078868      0.002976
# min       2.498152       0.158843     7.000000      0.359269      0.000008
# 25%       3.065258       0.632250   311.000000      0.848584      0.002202
# 50%       3.496508       0.717553   556.000000      0.898447      0.003698
# 75%       3.654288       0.798711   829.000000      0.943196      0.005308
# max       5.082087       1.101130  3508.000000      0.998721      0.085714

# %%
sns.jointplot(x = 'mileage', y = 'rate_residual', data = df_p ,kind = 'hex')

# %%
sns.jointplot(x = 'num_day', y = 'rate_residual', data = df_p ,kind = 'hex')

# %%
sns.jointplot(x = 'displacement', y = 'rate_residual', data = df_p ,kind = 'hex')

# %%
df_p['price'].groupby(df['brand']).mean()[:10].plot.barh(title='平均价格品牌排名分析',color='b')
df_e['price'].groupby(df['brand']).mean()[:10].plot.barh(title='平均价格品牌排名分析',color='b')
df_m['price'].groupby(df['brand']).mean()[:10].plot.barh(title='平均价格品牌排名分析',color='b')
# df_p.price.value_counts()[:10].plot.barh(title='品牌排名分析',color=colors)
# df_e.brand.value_counts()[:10].plot.barh(title='品牌排名分析',color=colors)
# df_m.brand.value_counts()[:10].plot.barh(title='品牌排名分析',color=colors)
plt.show()

# %%
def show_corr(clean_data_set):
    corr_data_matrix = clean_data_set.corr()
    corr_data_matrix['rate_residual'].sort_values(ascending=False)
    #查看哪些字段与汽油车保值率最相关，我们先计算相关性矩阵
    df_tep1=clean_data_set.drop(columns='energy_type')
    sns.set(rc={"figure.figsize":(20, 20)})
    sns.heatmap(df_tep1.corr(), annot = True,cmap=colors)

show_corr(df_p)

# %%
show_corr(df)

# %% [markdown]
# 对于汽油车，我们所构造的二手车保值率特征与二手车成新率表现出了极大的相关性（0.8），与排量和变速箱只有一点相关性（0.12），与使用天数呈极大的负相关（-0.8），其次与里程数呈极大的负相关（-0.63），与城市呈一定的负相关（-0.27）。

# %%
show_corr(df_e)

# %% [markdown]
# 对于电车，首先我们可以发现二手车保值率与成新率有极大的相关性（0.82），其次是official endurance（0.14），与color有一些相关性（0.12），可以注意到二手车售价与使用天数是负相关（-0.82），其次是与里程数负相关性（-0.61）

# %%
show_corr(df_m)

# %% [markdown]
# 对于混合车，首先我们可以发现二手车保值率与成新率有极大的相关性（0.68），其次是battery_capacity（0.37），与official_endurance有一些相关性（0.31），可以注意到二手车售价与使用天数是负相关（-0.68），其次是与里程数负相关性（-0.53)。

# %% [markdown]
# 总结：三种车型保值率都与成新率有极大的相关性，其次与车辆的动力功率也有一定的相关性（油车为排量，电车为battery_capacity，
# official_endurance）三个车型都与使用天数呈极大的负相关，其次与里程数呈较大的负相关。

# %%
numeric_features_p = ['price','price_new','mileage','displacement','price_log','rate_residual','num_day','newness_rate','mile_per_day']

# %%
#### 3) 每个数字特征得分布可视化
#汽车
f = pd.melt(df_p, value_vars=numeric_features_p)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value",color="y")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 可以看出price主要分布在10w，意味着二手车市场上主要流通10w左右的二手车，price_new主要分布在20w左右，所有20w原价的车更受二手市场的亲赖，price_new其分布非常广，400w的二手车也活跃在市场上。与此同时小于5w里程出售的二手车比较多，绝大部分二手车在10w里程以内。另外，一些二手车的displacement排量差距很大，但市场中主要是3L排量的车。可以看到大部分车的rate_residual为0.5，且鲜有车超过1。大部分二手车小于2000天，且newness_rate大部分分布在0.5到1之间，而每辆车mile_per_day几乎没有很大的差距。

# %%
numeric_features_e= ['price','price_new','mileage','official_endurance','motor_power','battery_capacity','price_log','rate_residual','num_day','newness_rate','mile_per_day']

# %%
### 3) 每个数字特征得分布可视化
#电车
f = pd.melt(df_e, value_vars=numeric_features_e)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value",color='y')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 可以看出与油车相比，活跃在二手市场的电车新车价格明显低于油车，大概10w左右，另外电车的里程也比油车明显要低，另外电车的official_endurance相比油车的排量分布更均匀，rate_residual大部分分布在1附近明显高于汽车，可见电车在二手市场更好流通，大部分电车二手车使用天数小于1000天，对于newness_rate大部分分布在0.8到1。而mile_per_day高于汽车的mile_per_day.

# %%
### 3) 每个数字特征得分布可视化
#混合车
numeric_features_m= ['price','price_new','mileage','official_endurance','motor_power','battery_capacity','price_log','rate_residual','num_day','newness_rate','mile_per_day']

# %%
f = pd.melt(df_m, value_vars=numeric_features_m)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value",color='y')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### 混动price在市场上流通的二手车大部分是25w左右，price_new也比电车和油车高，mileage分布和电车相似，rate_residual大概在0.7左右，高于油车低于电车，使用天数大于电车小于油车，newness_rate和电车一样大部分分布在0.8到1，mile_per_day大于汽车小于电车。

# %% [markdown]
# 总结：rate_residual电车最高，混动第二，油车最后。背后原因应该与使用天数有关，油车使用天数多于混动多于电车，从newness_rate值分布也可以看出这个规律，其值油车小于混动小于电车，意味着二手市场上的大部分汽车成新率低于混动和电车，也就是二手市场中的汽车偏旧，保值率偏低。总的来说，二手市场中的电车相比油车和混动原价要低，二手价也更低，但保值率更高。

# %%
## 4) 数字特征相互之间的关系可视化
#汽车
sns.set()
columns_p= ['price','price_new','mileage','displacement','price_log','num_day','rate_residual','newness_rate','mile_per_day']
sns.pairplot(df_p[columns_p],size = 2 ,kind ='scatter',diag_kind='kde')
plt.show()

# %% [markdown]
# 分析与前方热力图一样，结合热力图数值一起描述。

# %%
## 4) 数字特征相互之间的关系可视化
#电车
from pylab import *
mpl.rcParams['font.sans-serif']=['SimHei'] #绘图显示中文

sns.set()
columns_e= ['price','price_new','mileage','official_endurance','motor_power','battery_capacity','price_log','rate_residual','num_day','newness_rate','mile_per_day']
sns.pairplot(df_e[columns_e],size = 2 ,kind ='scatter',diag_kind='kde')
plt.show()

# %% [markdown]
# 分析与前方热力图一样，结合热力图数值一起描述。

# %%
## 4) 数字特征相互之间的关系可视化
#混合车
sns.set()
columns_m= ['price','price_new','mileage','official_endurance','motor_power','battery_capacity','price_log','rate_residual','num_day','newness_rate','mile_per_day']
sns.pairplot(df_m[columns_m],size = 2 ,kind ='scatter',diag_kind='kde')
plt.show()

# %% [markdown]
# 分析与前方热力图一样，结合热力图数值一起描述。

# %%
categorical_features = ['standard','gearbox','num_trans','license_location','color','keys','city']

# %%
## 2) 类别特征箱形图可视化
#汽车
def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)

f = pd.melt(df_p, id_vars=['rate_residual'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "rate_residual",color=colors)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20108 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 可以看出汽车二手车中大部分国六b的rate_residual比较大，（红色箱子）的rate_residual与其差不多，两种gearbox差别较小，num_trans可以看出比较小的负相关，除了北上广深的其他城市的二手车rate_residual比北上广深高一些，4把钥匙的二手车rate_residual更高，北京的二手车平台上的二手车相比上海深圳rate_residual更高。

# %%
## 2) 类别特征箱形图可视化
#电车
f = pd.melt(df_e, id_vars=['rate_residual'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "rate_residual")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 可以看出大部分电车为（蓝色箱子）的rate_residual比较大，电车gearbox为1数量较多，num_trans可以看出比较大的负相关，除了北上广深的其他城市的二手车rate_residual比北上广深高一些，2把钥匙的二手车rate_residual更高，深圳的二手车平台上的二手车相比上海北京rate_residual更高。

# %%
## 2) 类别特征箱形图可视化
#混动

f = pd.melt(df_m, id_vars=['rate_residual'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "rate_residual",color='deepskyblue')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-199-506aac7e4589> in <module>
#       5 g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
#       6 g = g.map(boxplot, "value", "rate_residual",color='deepskyblue')
# ----> 7 for box,c in zip(g['boxes'], color):
#       8     # 箱体内部填充颜色
#       9     box.set( facecolor = c )
#
# TypeError: 'FacetGrid' object is not subscriptable
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 混动车自动挡偏多，与num_trans无明显线性关系，除北上广深的其他城市的二手车rate_residual比北上广深高，混动车gearbox为1数量较多，两类别color对混动rate_residual几乎持平。

# %% [markdown]
# 总结：类别型特征对各类型二手车影响不大，与num_trans有负相关性，除北上广深的其他城市的二手车rate_residual比北上广深高，不同color对rate_residual只有比较小的影响。

# %%
## 4) 类别特征的柱形图可视化
#汽车
def bar_plot(x, y, **kwargs):
    sns.barplot(x=x, y=y)
    x=plt.xticks(rotation=90)
f = pd.melt(df_p, id_vars=['rate_residual'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(bar_plot, "value", "rate_residual",colors=colors)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 与箱形图一致

# %%
## 4) 类别特征的柱形图可视化
#电车

f = pd.melt(df_e, id_vars=['rate_residual'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(bar_plot, "value", "rate_residual")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 与箱形图一致

# %%
## 4) 类别特征的柱形图可视化
#混动
f = pd.melt(df_m, id_vars=['rate_residual'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(bar_plot, "value", "rate_residual")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20845 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 与箱形图一致
